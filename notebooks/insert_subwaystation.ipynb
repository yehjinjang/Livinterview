# %%
import os
import sys
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

sys.path.append("../")
from backend.models import SubwayStation


subway_stations = [
    "강남역",
    "강남구청역",
    "강동역",
    "강동구청역",
    "강변역",
    "개봉역",
    "개화산역",
    "고덕역",
    "고속터미널역",
    "공덕역",
    "광나루역",
    "광화문역",
    "구로디지털단지역",
    "구의역",
    "군자역",
    "금호역",
    "길음역",
    "남구로역",
    "남부터미널역",
    "남성역",
    "남영역",
    "내방역",
    "노들역",
    "노량진역",
    "녹번역",
    "녹사평역",
    "논현역",
    "당고개역",
    "당산역",
    "대림역",
    "대청역",
    "대치역",
    "도곡역",
    "도림천역",
    "도봉산역",
    "독립문역",
    "동대문역",
    "동대문역사문화공원역",
    "동묘앞역",
    "동작역",
    "마곡나루역",
    "마들역",
    "마장역",
    "마천역",
    "망원역",
    "망우역",
    "매봉역",
    "명동역",
    "명일역",
    "목동역",
    "몽촌토성역",
    "무악재역",
    "문래역",
    "문정역",
    "미아역",
    "미아사거리역",
    "반포역",
    "방배역",
    "방이역",
    "방화역",
    "배방역",
    "백석역",
    "버티고개역",
    "범계역",
    "보라매역",
    "보문역",
    "복정역",
    "봉천역",
    "봉화산역",
    "홍제역",
    "창동역",
    "아차산역",
]

engine = create_engine(os.getenv("DB_URL"))
Session = sessionmaker(engine)
session = Session()

for subway_station in subway_stations:
    new_subway_station = SubwayStation(name=subway_station)
    session.add(new_subway_station)
session.commit()
session.close()
